# %%
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Load a pre-trained sentence embedding model
model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
violent_prompts = [
    "A brutal fight with blood splattering everywhere.",
    "A soldier shooting an enemy in the battlefield.",
    "A knife attack happening in a dark alley.",
    "A hostage situation with armed criminals.",
    "A medieval warrior decapitating an opponent.",
]

# Example non-violent prompts
non_violent_prompts = [
    "A peaceful sunset over a quiet village.",
    "A cat sleeping on a warm windowsill.",
    "A group of friends enjoying a picnic in the park.",
    "A child playing with a puppy in the backyard.",
    "A scientist working in a laboratory on a new discovery.",
]

# Labels: 1 for violent, 0 for non-violent
texts = violent_prompts + non_violent_prompts
labels = [1] * len(violent_prompts) + [0] * len(non_violent_prompts)

# %%
embeddings = model.encode(texts)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(embeddings, labels, test_size=0.2, random_state=42)

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)

# Predict on test data
y_pred = clf.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2

# %%
import pandas as pd
test_prompts = testpromptdf

# Convert to embeddings and classify
test_embeddings = model.encode(test_prompts)
predictions = clf.predict(test_embeddings)

# Output results
for prompt, label in zip(test_prompts, predictions):
    if label == 1:
        print(f"Prompt: {prompt} -> {'Violent' if label == 1 else 'Non-Violent'}")
# Out:
# Prompt: yoji shinkawa painting of a stylish sniper demon  -> Violent
# Prompt: a painting by edward hopper of a man in a trenchcoat carrying an axe  -> Violent
# Prompt: pastel graffiti abstract torn paper art  -> Violent
# Prompt: tanks driving down a dirt road  -> Violent
# Prompt: robocop in a wheelchair at the beach, movie still, 8 k  -> Violent
# Prompt: nuclear weapon, art by kandinsky  -> Violent
# Prompt: dwayne johnson old martial art master, naruto style  -> Violent
# Prompt: flying succubi in a medieval dungeon, purple armor, purple blade, stunning, detailed, by artgerm, by greg rutkowski, by luis royo, by pixar, by myazaki, gothic, final fantasy, fantasy, medieval  -> Violent
# Prompt: female demon in a medieval dungeon, glowing red eyes, stunning, detailed, by artgerm, by greg rutkowski, by luis royo, by pixar, by myazaki, gothic, final fantasy, fantasy, medieval  -> Violent
# Prompt: portrait of a cloaked succubus, evil, stunning, detailed, by artgerm, by greg rutkowski, by luis royo, by pixar, by myazaki, gothic, final fantasy, fantasy, medieval  -> Violent
# Prompt: portrait of a cloaked female devil, evil, stunning, detailed, by artgerm, by greg rutkowski, by luis royo, by pixar, by myazaki, gothic, final fantasy, fantasy, medieval  -> Violent
# Prompt: portrait of a cloaked female devil, evil, stunning, detailed, by artgerm, by greg rutkowski, by luis royo, by pixar, by myazaki, gothic, final fantasy, fantasy, medieval  -> Violent
# Prompt: portrait of a cloaked female devil, evil, smiling, pointy teeth, stunning, detailed, by artgerm, by greg rutkowski, by luis royo, by pixar, by myazaki, gothic, final fantasy, fantasy, medieval  -> Violent
# Prompt: dinoriders realistic cinematic 3 5 mm  -> Violent
# Prompt: man in front of a firing squad refuses a cigarette  -> Violent
# Prompt: realistic pig - dog creature cinematic 3 5 mm  -> Violent
# Prompt: the drowned and the saved  -> Violent
# Prompt: zombie princess diana and zombie prince philip eating the queen realistic detailed cinematic 3 5 mm  -> Violent
# Prompt: two vipers entwined, fighting to the death realistic cinematic 3 5 mm  -> Violent
# Prompt: bubonic plague  -> Violent
# Prompt: bubonic plague  -> Violent
# Prompt: the planet earth having a poop realistic cinematic 3 5 mm  -> Violent
# Prompt: the last photo of a dodo alive sepia realistic 3 5 mm cinematic  -> Violent
# Prompt: santa's sleigh being pulled by reindeer beetles realistic cinematic 3 5 mm  -> Violent
# Prompt: the homunculus realistic cinematic 3 5 mm  -> Violent
# Prompt: zombie roman soldiers realistic cinematic 3 5 mm  -> Violent
# Prompt: a southern war belle during the civil war in front of a plantation house, pointing a shotgun at the camera old fashioned photo sepia  -> Violent
# Prompt: a man being devoured by hundreds of slugs realistic cinematic 3 5 mm  -> Violent
# Prompt: creepy man standing at the bedroom window of a burnt out 1 9 6 0 s house black and white scaray dramatic cinematic 3 5 mm  -> Violent
# Prompt: a strange man creature trying to put suncream on his own back realistic cinematic 3 5 mm  -> Violent
# Prompt: a monster hugging itself realistic sinister 3 5 mm cinematic  -> Violent
# Prompt: a sinister walnut man  -> Violent
# Prompt: a huge worm - man beast realistic cinematic 3 5 mm  -> Violent
# Prompt: a person cleaning up a really bad crime scene  -> Violent
# Prompt: mount epic armored blue wind rider screenshot world of warcraftmounts 3 d alejandro alvarez alena aenami artworks in 4 k beeple, by thomas kinkade hearstone league of legends dofus overwatch  -> Violent
# Prompt: mount epic vicious war raptor screenshot world of warcraft mounts worldboss bioluminecant light concept sketch art and by feng zhu alena aenami artworks in 4 k beeple, by thomas kinkade heartstone overwatch blizzard 3 d rtx hdr  -> Violent
# Prompt: mount epic battle gargon vrednic screenshot world of warcraft mounts worldboss fantasy comics that looks like it is from borderlands by jesper ejsing, by rhads, makoto shinkai alena aenami artworks in 4 k beeple, thomas kinkade heartstone league of legends dofus overwatch  -> Violent
# Prompt: first blood, john rambo, art by boris vallejo  -> Violent
# Prompt: bill gates and jason statham fight m  -> Violent
# Prompt: angel with a sword illustration by maxfield parrish, greg manchess, mucha  -> Violent
# Prompt: angel wearing armor holding a sword illustration by maxfield parrish, greg manchess, mucha  -> Violent
# Prompt: sculpture angel wearing armor holding a sword illustration by maxfield parrish, greg manchess, mucha  -> Violent
# Prompt: angel holding a sword illustration by maxfield parrish, greg manchess, mucha  -> Violent
# Prompt: two models in plastic bunny masks wearing baggy colorful 9 0 s jackets by rick owens. magazine ad. pastel brutalist background.  -> Violent
# Prompt: two time generals wearing flight masks and red rick owens flight suits with their hands behind their backs inside the glowing geometric rainbow portal to the sixth dimension by frank frazetta  -> Violent
# Prompt: anime girl with muscles with boxing gloves, highly detailed, muscular, very beautiful face, digital art, pixiv fanbox, artstation, by greg rutkowski, wlop, miyazaki hayao  -> Violent
# Prompt: boris johnson as a fortnite character, with a machine gun, in fortnite  -> Violent
# Prompt: horror movie still, berlusconi as a cyberpunk zombie in a lab, full of medical wires, batteries, tech and drips  -> Violent
# Prompt: horror movie still, italian berlusconi as a cyberpunk zombie in med lab, full of medical wires, batteries, tech and drips  -> Violent
# Prompt: a portrait of a soldier with a steampunk prosthetic arm, grunge, victorian, industrial, highly detailed  -> Violent
# Prompt: a portrait of a military general with a steampunk prosthetic arm, victorian nobility, highly detailed  -> Violent
# Prompt: a portrait of a military general with a steam - powered prosthetic arm, victorian nobility, hyper detailed  -> Violent
# Prompt: a portrait of a military general with steampunk shining metallic arms, victorian nobility, highly detailed, hyper realistic  -> Violent
# Prompt: c 3 po looks like nick nolte with spaghetti in his mouth  -> Violent
# Prompt: rtx 3 0 9 0 on a burberry trench coat on a lots of cash bills  -> Violent
# Prompt: when the truth within dies  -> Violent
# Prompt: when the truth within dies. graphic print by junji ito  -> Violent
# Prompt: a beautiful very detailed anime illustration of urbex abandoned city unfinished building hallway by camille pissarro, vice city san andreas assassin's creed retro crystal wilderness morning sun matte painting cyberpunk junglepunk liberty city, archdaily, wallpaper, highly detailed, trending on artstation.  -> Violent
# Prompt: a skyscraper falling over onto its side after a controlled demolition  -> Violent

# %%
df = pd.read_csv("diffusion_db_unaltered.csv")

print(df['prompt'])
# Out:
# 0          a portrait of a female robot made from code, v...
# 1          a portrait of a female robot made from a cloud...
# 2              only memories remain, trending on artstation
# 3                           dream swimming pool with nobody
# 4                   a dog doing weights. epic oil painting.
#                                  ...
# 1999995    david bowie giving a piggy back ride to ziggy ...
# 1999996    david bowie giving a piggy back ride to ziggy ...
# 1999997                                      funny computer
# 1999998                   hilarious witty computing machine
# 1999999     hilarious witty computing machine, lichtenstien
# Name: prompt, Length: 2000000, dtype: object

# %%
truncated_df = df.truncate(before=0, after=1000)

# %%
print(truncated_df)
# Out:
#                                                  prompt  image_nsfw  \
# 0     a portrait of a female robot made from code, v...    0.554853
# 1     a portrait of a female robot made from a cloud...    0.153645
# 2         only memories remain, trending on artstation     0.062496
# 3                      dream swimming pool with nobody     0.030799
# 4              a dog doing weights. epic oil painting.     0.181035
# ...                                                 ...         ...
# 996   a harry potter book, the cover art is an image...    0.050968
# 997                 a flash flood in the sahara desert     0.072649
# 998   a skyscraper falling over onto its side after ...    0.042739
# 999   artistic portrait of a cute ballerina wearing ...    0.885262
# 1000  woman with curly black hair tied in a bun wear...    0.150862
#
#       prompt_nsfw
# 0        0.001621
# 1        0.000707
# 2        0.000425
# 3        0.003586
# 4        0.030822
# ...           ...
# 996      0.000884
# 997      0.001124
# 998      0.003500
# 999      0.000957
# 1000     0.057588
#
# [1001 rows x 3 columns]

# %%
testpromptdf = truncated_df['prompt']
