# %%
import pandas as pd
df = pd.read_csv("diffusion_db_unaltered.csv")

# %%
df.head()
# Out:
#                                               prompt  image_nsfw  prompt_nsfw
# 0  a portrait of a female robot made from code, v...    0.554853     0.001621
# 1  a portrait of a female robot made from a cloud...    0.153645     0.000707
# 2      only memories remain, trending on artstation     0.062496     0.000425
# 3                   dream swimming pool with nobody     0.030799     0.003586
# 4           a dog doing weights. epic oil painting.     0.181035     0.030822

# %%
df['prompt']
# Out:
# 0          a portrait of a female robot made from code, v...
# 1          a portrait of a female robot made from a cloud...
# 2              only memories remain, trending on artstation
# 3                           dream swimming pool with nobody
# 4                   a dog doing weights. epic oil painting.
#                                  ...
# 1999995    david bowie giving a piggy back ride to ziggy ...
# 1999996    david bowie giving a piggy back ride to ziggy ...
# 1999997                                      funny computer
# 1999998                   hilarious witty computing machine
# 1999999     hilarious witty computing machine, lichtenstien
# Name: prompt, Length: 2000000, dtype: object

# %%
keywords = [
    "attack", "assault", "beat", "beating", "bloodshed", "brutality", "cruelty",
    "execution", "harm", "homicide", "hurt", "injury", "kill", "killing", "massacre",
    "maim", "manslaughter", "murder", "slaughter", "stabbing", "torture", "violent",
    "amputation", "battered", "behead", "brain", "contusion", "crushed", "cut", 
    "decapitate", "disembowel", "disfigure", "dismember",
    "electrocute", "fracture", "gouge", "hemorrhage", "impale", "laceration", "mutilation",
    "puncture", "severed", "skull", "stab", "strangulation", "suffocation", "trauma", "wound",
    "abuse", "agony", "branding", "breaking", "bones", "cannibalism", "crucifixion",
    "drawn", "quartered", "drowning", "execution", "flaying", "flogging", "impalement",
    "blood", "bloodbath", "bloody", "brain", "matter",
    "cadaver", "carnage", "corpse", "decaying", "flesh", "entrails", "eviscerate",
    "exsanguinate", "flesh", "wound", "gore", "guts", "intestine", "maggot-infested",
    "mangled", "necrosis", "pus", "rotting", "severed", "limb", "skin", "peeling", "splatter", "viscera"
]

# %%
keyword_set = set(keywords)

# Function to check for keyword intersection
def contains_keyword(prompt):
    if not isinstance(prompt, str):  # Ensure prompt is a string
        return False
    words = set(prompt.lower().split())  # Tokenize the prompt into words
    return bool(words & keyword_set)  # Check if any words match keywords

# Apply function to filter DataFrame
filtered_df = df[df['prompt'].apply(contains_keyword)]

# Display filtered DataFrame
print(filtered_df)
# Out:
#                                                     prompt  image_nsfw  \
# 276      a beautiful painting of cyberpunk skull by nek...    0.083585
# 339      8 k made in abyss chubby, bear, wearing milita...    0.245823
# 340      8 k made in abyss chubby, teddy bear, wearing ...    0.513664
# 426      a man with an shrivelled up walnut brain insid...    0.074707
# 696      stunning god of feline skull portrait, skull, ...    0.101075
# ...                                                    ...         ...
# 1999787          blood red cresent moon, cyberpunk, space     0.045955
# 1999878  young female witch with pale green skin wearin...    0.053405
# 1999941  symmetric, a dreamy male android holding a bra...    2.000000
# 1999942  zoomed out, a dark male android in dark blue c...    2.000000
# 1999943  zoomed out, a dark male android in dark blue c...    0.056537
#
#          prompt_nsfw
# 276         0.001309
# 339         0.152054
# 340         0.117266
# 426         0.424220
# 696         0.000842
# ...              ...
# 1999787     0.013205
# 1999878     0.324162
# 1999941     0.003106
# 1999942     0.009464
# 1999943     0.009464
#
# [63738 rows x 3 columns]

# %%
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    "prompt": [
        "This is a harmless prompt.",
        "The fight was brutal and bloody.",
        "He was attacked with a knife.",
        "I love peaceful conversations.",
        "There was a massacre in the village.",
        "He was shot with a sniper rifle."
    ]
})

# List of keywords
keywords = [
    "attack", "assault", "beat", "beating", "bloodshed", "brutality", "cruelty",
    "execution", "harm", "homicide", "hurt", "injury", "kill", "killing", "massacre",
    "maim", "manslaughter", "murder", "slaughter", "stabbing", "torture", "violent",
    "amputation", "battered", "behead", "brain", "contusion", "crushed", "cut", 
    "decapitate", "disembowel", "disfigure", "dismember",
    "electrocute", "fracture", "gouge", "hemorrhage", "impale", "laceration", "mutilation",
    "puncture", "severed", "skull", "stab", "strangulation", "suffocation", "trauma", "wound",
    "abuse", "agony", "branding", "breaking", "bones", "cannibalism", "crucifixion",
    "drawn", "quartered", "drowning", "execution", "flaying", "flogging", "impalement",
    "blood", "bloodbath", "bloody", "brain", "matter",
    "cadaver", "carnage", "corpse", "decaying", "flesh", "entrails", "eviscerate",
    "exsanguinate", "flesh", "wound", "gore", "guts", "intestine", "maggot-infested",
    "mangled", "necrosis", "pus", "rotting", "severed", "limb", "skin", "peeling", "splatter", "viscera"
]

# Convert keyword list to a set for faster lookups
keyword_set = set(keywords)

# Function to check for keyword intersection
def contains_keyword(prompt):
    words = set(prompt.lower().split())  # Tokenize the prompt into words
    return bool(words & keyword_set)  # Check if any words match keywords

# Apply function to filter DataFrame
filtered_df = df[df['prompt'].apply(contains_keyword)]

# Display filtered DataFrame
print(filtered_df)
# Out:
#                                  prompt
# 4  There was a massacre in the village.

# %%
print(df.loc[1999941])
# Out:
# prompt         symmetric, a dreamy male android holding a bra...
# image_nsfw                                                   2.0
# prompt_nsfw                                             0.003106
# Name: 1999941, dtype: object

# %%
# Out:
# Empty DataFrame
# Columns: [prompt]
# Index: []

# %%
imagebad = filtered_df[(filtered_df['image_nsfw'] > 1)]

# %%
display(imagebad)
# Out:
#                                                     prompt  image_nsfw  \
# 2050     humanoid cat girl ; short child ; black fur ; ...         2.0
# 134475   a wholesome animation key shot of a child hold...         2.0
# 136061   humanoid furry cat girl ; short child ; black ...         2.0
# 243193   a random saiyan child going super saiyan, witc...         2.0
# 436578   portrait of small child with red balloon and h...         2.0
# 537074   khajit ; anthropomorphic cat girl ; short chil...         2.0
# 590870   stupid small child named jarrad being bullied ...         2.0
# 594550   hyperrealism extreamly highly detailed still v...         2.0
# 680228   a biomechanical child from the gwynnconian ali...         2.0
# 720016   anthropomorphic cat girl ; short child ; black...         2.0
# 914995      child of mikhail gorbachev and vladimir putin          2.0
# 1021716  concept art of a black robed ancient magus, fa...         2.0
# 1023597  plague doctor in his larval form. extremely lu...         2.0
# 1277325  massive gordon ramsay looming over the clouds ...         2.0
# 1277332  massive gordon ramsay looming over the clouds ...         2.0
# 1277343  small child looking at a massive gordon ramsay...         2.0
# 1331816  a lone young child, beautiful angelic goddess,...         2.0
# 1498328  simple ugly messy colorful crayon hand drawing...         2.0
# 1673296  child sitting on the floor playing a console g...         2.0
# 1710368  child sitting on the floor playing a console g...         2.0
# 1741921  a beautiful amazing oil painting of a robot an...         2.0
# 1741922  a beautiful amazing oil painting of a robot an...         2.0
# 1836372  simple ugly messy colorful crayon hand drawing...         2.0
# 1874645  child at hiroshima. art by hayao myiazaki, goy...         2.0
# 1887217  man carrying his child over his shoulders, cle...         2.0
# 1914341  simple ugly messy colorful crayon line art han...         2.0
# 1924834  luscious child painted by hajime sorayama pluc...         2.0
# 1950289  dark oil realistic painting a gaunt man in a s...         2.0
# 1958807  a woman with brown hair sitting in an armchair...         2.0
#
#          prompt_nsfw
# 2050        0.006643
# 134475      0.001320
# 136061      0.023578
# 243193      0.031104
# 436578      0.016795
# 537074      0.006414
# 590870      0.997573
# 594550      0.003769
# 680228      0.000884
# 720016      0.004731
# 914995      0.021814
# 1021716     0.021245
# 1023597     0.013266
# 1277325     0.008621
# 1277332     0.011658
# 1277343     0.009026
# 1331816     0.001568
# 1498328     0.368913
# 1673296     0.003816
# 1710368     0.003816
# 1741921     0.000424
# 1741922     0.000424
# 1836372     0.368913
# 1874645     0.022487
# 1887217     0.002412
# 1914341     0.293857
# 1924834     0.179390
# 1950289     0.032374
# 1958807     0.002265

# %%
promptbad = filtered_df[(filtered_df['prompt_nsfw'] > 0.1)]

# %%
display(promptbad)
# Out:
#                                                     prompt  image_nsfw  \
# 590870   stupid small child named jarrad being bullied ...         2.0
# 1498328  simple ugly messy colorful crayon hand drawing...         2.0
# 1836372  simple ugly messy colorful crayon hand drawing...         2.0
# 1914341  simple ugly messy colorful crayon line art han...         2.0
#
#          prompt_nsfw
# 590870      0.997573
# 1498328     0.368913
# 1836372     0.368913
# 1914341     0.293857

# %%
promptbad.loc[590870][0]
# Out:
# 'stupid small child named jarrad being bullied for being a stupid idiot '

# %%
imagebad.loc[136061][0]
# Out:
# 'humanoid furry cat girl ; short child ; black fur ; wearing rags ; magic lightning crackling around ; sorcerer ; large eyes ; explosions ; cinematic ; trending on artstation ; digital art '

# %%
keywords = [
    "attack", "assault", "beat", "beating", "bloodshed", "brutality", "combat", "cruelty",
    "execution", "fight", "harm", "homicide", "hurt", "injury", "kill", "killing", "massacre",
    "maim", "manslaughter", "murder", "slaughter", "shooting", "stabbing", "torture", "violent", "war",
    "ammo", "arrow", "ax", "bat", "blade", "bomb", "bullet", "chainsaw", "club", "dagger",
    "firearm", "flamethrower", "garrote", "grenade", "guillotine", "gun", "hammer", "handgun",
    "knife", "machete", "mine", "missile", "pistol", "poison", "revolver", "rifle", "shotgun",
    "sniper", "spear", "sword", "tank", "taser", "tear gas",
    "amputation", "battered", "behead", "bone", "fracture", "brain", "damage", "burn", "concussion",
    "contusion", "crushed", "cut", "decapitate", "disembowel", "disfigure", "dismember",
    "electrocute", "fracture", "gouge", "hemorrhage", "impale", "laceration", "mutilation",
    "puncture", "severed", "skull", "stab", "strangulation", "suffocation", "trauma", "wound",
    "abuse", "agony", "branding", "breaking", "bones", "cannibalism", "crucifixion",
    "drawn", "quartered", "drowning", "execution", "flaying", "flogging", "impalement",
    "lynching", "maiming", "pillory", "quartering", "starvation", "stoning", "vivisection",
    "waterboarding",
    "blood", "bloodbath", "bloodcurdling", "bloodlust", "bloody", "brain", "matter",
    "cadaver", "carnage", "corpse", "decaying", "flesh", "entrails", "eviscerate",
    "exsanguinate", "flesh", "wound", "gore", "guts", "intestine", "maggot-infested",
    "mangled", "necrosis", "pus", "rotting", "severed", "limb", "skin", "peeling", "splatter", "viscera"
]

# %%
filtered_df['prompt_nsfw'].mean()
# Out:
# 0.03826854278477398
